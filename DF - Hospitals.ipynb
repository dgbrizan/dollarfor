# %%
import pandas as pd

hosp_acute = pd.read_excel('HospitalList2020daFINAL.xlsx', sheet_name='Acute')
hosp_acute
# Out:
#           ID                                               NAME  \
# 0      10001                    SOUTHEAST HEALTH MEDICAL CENTER
# 1      10005              MARSHALL MEDICAL CENTERS SOUTH CAMPUS
# 2      10006                       NORTH ALABAMA MEDICAL CENTER
# 3      10007                           MIZELL MEMORIAL HOSPITAL
# 4      10008                        CRENSHAW COMMUNITY HOSPITAL
# ...      ...                                                ...
# 4608  670125                TEXAS CENTER FOR INFECTIOUS DISEASE
# 4609  670128  BAYLOR SCOTT & WHITE MEDICAL CENTER ? PFLUGERV...
# 4610  670129                               THE HEIGHTS HOSPITAL
# 4611  670131         BAYLOR SCOTT & WHITE MEDICAL CENTER ? BUDA
# 4612  670132                       METHODIST SOUTHLAKE HOSPITAL
#
#                                 ADDRESS          CITY STATE    ZIP     FIPS  \
# 0                1108 ROSS CLARK CIRCLE        DOTHAN    AL  36301   1069.0
# ...

# %%
hosp_specialty = pd.read_excel('HospitalList2020daFINAL.xlsx', sheet_name='Specialty')
hosp_specialty
test = hosp_specialty.drop(axis=0, index = [418])
# test.iloc[415:425,0]
test["ID"]=test["ID"].astype('int64')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1378 entries, 0 to 1378
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      1378 non-null   int64
#  1   NAME                    1378 non-null   object
#  2   ADDRESS                 1378 non-null   object
#  3   CITY                    1378 non-null   object
#  4   STATE                   1378 non-null   object
#  5   ZIP                     1378 non-null   int64
#  6   FIPS                    1378 non-null   int64
#  7   CBSA 2020               1378 non-null   object
#  8   RUCA Code               1378 non-null   float64
#  9   FORHP Rural/Urban 2020  1378 non-null   object
#  10  TYPE                    1378 non-null   object
#  11  PHONE NUMBER            1378 non-null   int64
#  12  CERTIFIED BEDS, POS     1378 non-null   int64
#  13  TOTAL BEDS, POS         1378 non-null   int64
# ...

# %%
test["FIPS"]=test["FIPS"].astype('float64')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1378 entries, 0 to 1378
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      1378 non-null   int64
#  1   NAME                    1378 non-null   object
#  2   ADDRESS                 1378 non-null   object
#  3   CITY                    1378 non-null   object
#  4   STATE                   1378 non-null   object
#  5   ZIP                     1378 non-null   int64
#  6   FIPS                    1378 non-null   float64
#  7   CBSA 2020               1378 non-null   object
#  8   RUCA Code               1378 non-null   float64
#  9   FORHP Rural/Urban 2020  1378 non-null   object
#  10  TYPE                    1378 non-null   object
#  11  PHONE NUMBER            1378 non-null   int64
#  12  CERTIFIED BEDS, POS     1378 non-null   int64
#  13  TOTAL BEDS, POS         1378 non-null   int64
# ...

# %%
hosp_acute.info()
hosp_acute.FIPS.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4613 entries, 0 to 4612
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      4613 non-null   int64
#  1   NAME                    4613 non-null   object
#  2   ADDRESS                 4613 non-null   object
#  3   CITY                    4613 non-null   object
#  4   STATE                   4613 non-null   object
#  5   ZIP                     4613 non-null   int64
#  6   FIPS                    4612 non-null   float64
#  7   CBSA 2020               4607 non-null   object
#  8   RUCA Code               4613 non-null   object
#  9   FORHP Rural/Urban 2020  4607 non-null   object
#  10  SPECIAL PAYMENT         4613 non-null   object
#  11  PHONE NUMBER            4613 non-null   int64
#  12  CERTIFIED BEDS, POS     4613 non-null   int64
#  13  TOTAL BEDS, POS         4613 non-null   int64
# ...

# %%
# test_RUCA = hosp_acute["RUCA Code"].astype('float64')
hosp_acute.loc[(hosp_acute["RUCA Code"] =="."), "RUCA Code"] = 99
hosp_acute["RUCA Code"] =hosp_acute["RUCA Code"].astype('float64')
hosp_acute.info()
test.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4613 entries, 0 to 4612
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      4613 non-null   int64
#  1   NAME                    4613 non-null   object
#  2   ADDRESS                 4613 non-null   object
#  3   CITY                    4613 non-null   object
#  4   STATE                   4613 non-null   object
#  5   ZIP                     4613 non-null   int64
#  6   FIPS                    4612 non-null   float64
#  7   CBSA 2020               4607 non-null   object
#  8   RUCA Code               4613 non-null   float64
#  9   FORHP Rural/Urban 2020  4607 non-null   object
#  10  SPECIAL PAYMENT         4613 non-null   object
#  11  PHONE NUMBER            4613 non-null   int64
#  12  CERTIFIED BEDS, POS     4613 non-null   int64
#  13  TOTAL BEDS, POS         4613 non-null   int64
# ...

# %%
hosp_specialty.columns
# Out:
# Index(['ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'FIPS', 'CBSA 2020',
#        'RUCA Code', 'FORHP Rural/Urban 2020', 'TYPE', 'PHONE NUMBER',
#        'CERTIFIED BEDS, POS', 'TOTAL BEDS, POS', 'BEDS, PSF',
#        'ACUTE BEDS, HCRIS'],
#       dtype='object')

# %%
hosp_acute.columns
# Out:
# Index(['ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'FIPS', 'CBSA 2020',
#        'RUCA Code', 'FORHP Rural/Urban 2020', 'SPECIAL PAYMENT',
#        'PHONE NUMBER', 'CERTIFIED BEDS, POS', 'TOTAL BEDS, POS', 'BEDS, PSF',
#        'ACUTE BEDS, HCRIS'],
#       dtype='object')

# %%
hosp_acute.iloc[:,:1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4613 entries, 0 to 4612
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      4613 non-null   int64
# dtypes: int64(1)
# memory usage: 36.2 KB

# %%
# Is there any overlap between acute and specialty? Use IDs to figure it out?

# int_df = pd.merge(hosp_acute.iloc[:,:1], hosp_specialty.iloc[:,:1], how ='inner')
int_df = pd.concat([hosp_specialty.iloc[:,:10], hosp_acute.iloc[:,:10]], join='inner', keys=['ID'])
int_df
# Out:
#              ID                                              NAME  \
# ID 0     012006                           INFIRMARY LTAC HOSPITAL
#    1     012007                NOLAND HOSPITAL MONTGOMERY II, LLC
#    2     012008            SELECT SPECIALTY HOSPITAL - BIRMINGHAM
#    3     012009                NOLAND HOSPITAL BIRMINGHAM II, LLC
#    4     012010                    NOLAND HOSPITAL DOTHAN II, LLC
# ...         ...                                               ...
#    1374  673071  ENCOMPASS HEALTH REHABILITATION HOSPITAL OF KATY
#    1375  673072             COBALT REHABILITATION HOUSTON HEIGHTS
#    1376  673073          EVEREST REHABILITATION HOSPITAL LONGVIEW
#    1377  673074            EVEREST REHABILITATION HOSPITAL TEMPLE
#    1378  713025               NORTH SHORE REHABILITATION HOSPITAL
#
#                                                 ADDRESS        CITY STATE  \
# ID 0                          5 MOBILE INFIRMARY CIRCLE      MOBILE    AL
# ...

# %%
for state in hosp_acute['STATE'].unique():
    print(state)
# Out:
# AL
# AK
# AZ
# AR
# CA
# CO
# CT
# DE
# DC
# FL
# GA
# HI
# ID
# IL
# IN
# IA
# KS
# KY
# LA
# ME
# MD
# MA
# MI
# MN
# MS
# MO
# MT
# NE
# NV
# NH
# NJ
# NM
# NY
# NC
# ND
# OH
# OK
# OR
# PA
# PR
# RI
# SC
# SD
# TN
# TX
# UT
# VT
# VI
# VA
# WA
# WV
# WI
# WY
# AS
# GU
# MP

# %%
overlap_df = hosp_acute.merge(hosp_specialty.iloc[:,1:2],how='inner')
overlap_df
# Out:
#        ID                    NAME                   ADDRESS         CITY  \
# 0   50320       HIGHLAND HOSPITAL     1411 EAST 31ST STREET      OAKLAND
# 1  330164       HIGHLAND HOSPITAL         1000 SOUTH AVENUE    ROCHESTER
# 2  130065  MOUNTAIN VIEW HOSPITAL      2325 CORONADO STREET  IDAHO FALLS
# 3  460013  MOUNTAIN VIEW HOSPITAL       1000 EAST 100 NORTH       PAYSON
# 4  310012         VALLEY HOSPITAL     223 N VAN DIEN AVENUE    RIDGEWOOD
# 5  360076   ATRIUM MEDICAL CENTER  ONE MEDICAL CENTER DRIVE     FRANKLIN
#
#   STATE    ZIP     FIPS CBSA 2020 RUCA Code FORHP Rural/Urban 2020  \
# 0    CA  94602   6001.0     Metro         1                  Urban
# 1    NY  14620  36055.0     Metro         1                  Urban
# 2    ID  83404  16019.0     Metro         1                  Urban
# 3    UT  84651  49049.0     Metro         1                  Urban
# 4    NJ   7450  34003.0     Metro         1                  Urban
# ...

# %%
overlap_df2 = hosp_specialty.merge(hosp_acute.iloc[:,1:2], how = 'inner')
overlap_df2.drop_duplicates()
# Out:
#        ID                    NAME                          ADDRESS  \
# 0  014006  MOUNTAIN VIEW HOSPITAL              3201 SCENIC HIGHWAY
# 2  034026         VALLEY HOSPITAL         3550 EAST PINCHOT AVENUE
# 3  452114   ATRIUM MEDICAL CENTER  11929 W AIRPORT BLVD, SUITE 110
# 4  514001       HIGHLAND HOSPITAL              300 56TH STREET, SE
#
#          CITY STATE    ZIP   FIPS CBSA 2020  RUCA Code FORHP Rural/Urban 2020  \
# 0     GADSDEN    AL  35902   1055     Metro        2.0                  Urban
# 2     PHOENIX    AZ  85018   4013     Metro        1.0                  Urban
# 3    STAFFORD    TX  77477  48157     Metro        1.0                  Urban
# 4  CHARLESTON    WV  25304  54039     Metro        1.0                  Urban
#
#     TYPE  PHONE NUMBER  CERTIFIED BEDS, POS  TOTAL BEDS, POS BEDS, PSF  \
# 0  PSYCH    2565469265                   68               68         .
# 2  PSYCH    6029523900                  122              122         .
# ...

# %%
hosp_specialty.loc[hosp_specialty["NAME"]=="ATRIUM MEDICAL CENTER"]
# Out:
#           ID                   NAME                          ADDRESS  \
# 1144  452114  ATRIUM MEDICAL CENTER  11929 W AIRPORT BLVD, SUITE 110
#
#           CITY STATE    ZIP   FIPS CBSA 2020  RUCA Code  \
# 1144  STAFFORD    TX  77477  48157     Metro        1.0
#
#      FORHP Rural/Urban 2020   TYPE  PHONE NUMBER  CERTIFIED BEDS, POS  \
# 1144                  Urban  LTACH    2812078200                   68
#
#       TOTAL BEDS, POS BEDS, PSF ACUTE BEDS, HCRIS
# 1144               68         .                68

# %%
hosp_acute.loc[hosp_acute["NAME"]=="ATRIUM MEDICAL CENTER"]
# Out:
#           ID                   NAME                   ADDRESS      CITY STATE  \
# 3077  360076  ATRIUM MEDICAL CENTER  ONE MEDICAL CENTER DRIVE  FRANKLIN    OH
#
#         ZIP     FIPS CBSA 2020 RUCA Code FORHP Rural/Urban 2020  \
# 3077  45005  39165.0     Metro         2                  Urban
#
#      SPECIAL PAYMENT  PHONE NUMBER  CERTIFIED BEDS, POS  TOTAL BEDS, POS  \
# 3077            NONE    5134205102                  328              328
#
#      BEDS, PSF ACUTE BEDS, HCRIS
# 3077       230               235

# %%
hosp_acute.loc[hosp_acute["NAME"] == "AU MEDICAL CENTER"]
# Out:
#          ID               NAME           ADDRESS     CITY STATE    ZIP  \
# 905  110034  AU MEDICAL CENTER  1120 15TH STREET  AUGUSTA    GA  30912
#
#         FIPS CBSA 2020 RUCA Code FORHP Rural/Urban 2020 SPECIAL PAYMENT  \
# 905  13245.0     Metro         1                  Urban            NONE
#
#      PHONE NUMBER  CERTIFIED BEDS, POS  TOTAL BEDS, POS BEDS, PSF  \
# 905    7067216569                  632              632       448
#
#     ACUTE BEDS, HCRIS
# 905               464

# %%
hosp_acute.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4613 entries, 0 to 4612
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      4613 non-null   int64
#  1   NAME                    4613 non-null   object
#  2   ADDRESS                 4613 non-null   object
#  3   CITY                    4613 non-null   object
#  4   STATE                   4613 non-null   object
#  5   ZIP                     4613 non-null   int64
#  6   FIPS                    4612 non-null   float64
#  7   CBSA 2020               4607 non-null   object
#  8   RUCA Code               4613 non-null   object
#  9   FORHP Rural/Urban 2020  4607 non-null   object
#  10  SPECIAL PAYMENT         4613 non-null   object
#  11  PHONE NUMBER            4613 non-null   int64
#  12  CERTIFIED BEDS, POS     4613 non-null   int64
#  13  TOTAL BEDS, POS         4613 non-null   int64
# ...

# %%
hosp_specialty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379 entries, 0 to 1378
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      1379 non-null   object
#  1   NAME                    1379 non-null   object
#  2   ADDRESS                 1379 non-null   object
#  3   CITY                    1379 non-null   object
#  4   STATE                   1379 non-null   object
#  5   ZIP                     1379 non-null   int64
#  6   FIPS                    1379 non-null   int64
#  7   CBSA 2020               1379 non-null   object
#  8   RUCA Code               1379 non-null   float64
#  9   FORHP Rural/Urban 2020  1379 non-null   object
#  10  TYPE                    1378 non-null   object
#  11  PHONE NUMBER            1379 non-null   int64
#  12  CERTIFIED BEDS, POS     1379 non-null   int64
#  13  TOTAL BEDS, POS         1379 non-null   int64
# ...

# %%
hosp_specialty.ID.value_counts(dropna=False)
# Out:
# 374008    1
# 294010    1
# 193090    1
# 193028    1
# 103038    1
#          ..
# 162003    1
# 153045    1
# 194079    1
# 363308    1
# 454126    1
# Name: ID, Length: 1379, dtype: int64

# %%
numeric_type=hosp_specialty["ID"].astype(int)
# df['2nd'] = df['2nd'].str.replace(',','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-29566b65613f> in <module>
# ----> 1 numeric_type=hosp_specialty["ID"].astype(int)
#       2 # df['2nd'] = df['2nd'].str.replace(',','').astype(int)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# ...
